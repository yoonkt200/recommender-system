# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# -----

# %% [markdown]
# # 1. K-means Clustering

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print (x_train.shape)
print (x_test.shape)
# Out:
# Using TensorFlow backend.
# (60000, 784)
# (10000, 784)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

model = KMeans(init="k-means++", n_clusters=10, random_state=0)
model.fit(x_train)
y_pred = model.labels_

# %%
def viz_img(y_pred):
    n = 10
    fig = plt.figure(1)
    box_index = 1
    for cluster in range(10):
        result = np.where(y_pred == cluster)
        for i in np.random.choice(result[0].tolist(), n, replace=False):
            ax = fig.add_subplot(n, n, box_index)
            plt.imshow(x_train[i].reshape(28, 28))
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            box_index += 1
    plt.show()

# %%
viz_img(y_pred)

# %% [markdown]
# -----

# %% [markdown]
# # 2. Spherical Clustering

# %%
# !pip install spherecluster

# %%
from spherecluster import SphericalKMeans

skm = SphericalKMeans(n_clusters=10)
skm.fit(x_train)
# Out:
# SphericalKMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=10,
#         n_init=10, n_jobs=1, normalize=True, random_state=None, tol=0.0001,
#         verbose=0)

# %%
viz_img(skm.labels_)

# %% [markdown]
# ------

# %% [markdown]
# # 3. PCA + K-means Clustering

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components=30).fit(x_train)
reduced_X = pca.transform(x_train)

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.7305345633067191

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

model = KMeans(init="k-means++", n_clusters=10, random_state=0)
model.fit(reduced_X)
y_pred = model.labels_

# %%
viz_img(y_pred)

# %% [markdown]
# -----

# %% [markdown]
# # 4. tSNE + DBSCAN Clustering

# %%
from sklearn.manifold import TSNE

model = TSNE(learning_rate=300)
transformed = model.fit_transform(x_train)

# %%
plt.rcParams['figure.figsize'] = [20, 16]
xs = transformed[:,0]
ys = transformed[:,1]
plt.scatter(xs,ys)
plt.show()

# %%
from sklearn.cluster import DBSCAN
model = DBSCAN(eps=2.4, min_samples=100)
predict = model.fit(transformed)
pd.Series(predict.labels_).value_counts()
# Out:
#  3    6578
#  6    6152
#  1    5948
#  4    5891
#  5    5841
#  9    5839
#  7    5609
#  2    5570
#  0    5395
#  8    5333
# -1    1844
# dtype: int64

# %%
y_pred = predict.labels_

# %%
# Assign result to df
dataset = pd.DataFrame({'Column1':transformed[:,0],'Column2':transformed[:,1]})
dataset['cluster_num'] = pd.Series(predict.labels_)

# Cluster Viz 1
plt.rcParams['figure.figsize'] = [5, 4]
plt.scatter(dataset[dataset['cluster_num'] == 0]['Column1'], 
            dataset[dataset['cluster_num'] == 0]['Column2'], 
            s = 50, c = 'red', label = 'Customer Group 1')
plt.scatter(dataset[dataset['cluster_num'] == 1]['Column1'], 
            dataset[dataset['cluster_num'] == 1]['Column2'], 
            s = 50, c = 'orange', label = 'Customer Group 2')
plt.scatter(dataset[dataset['cluster_num'] == 2]['Column1'], 
            dataset[dataset['cluster_num'] == 2]['Column2'], 
            s = 50, c = 'yellow', label = 'Customer Group 3')
plt.scatter(dataset[dataset['cluster_num'] == 3]['Column1'], 
            dataset[dataset['cluster_num'] == 3]['Column2'], 
            s = 50, c = 'green', label = 'Customer Group 4')
plt.scatter(dataset[dataset['cluster_num'] == 4]['Column1'], 
            dataset[dataset['cluster_num'] == 4]['Column2'], 
            s = 50, c = 'blue', label = 'Customer Group 5')
plt.scatter(dataset[dataset['cluster_num'] == 5]['Column1'], 
            dataset[dataset['cluster_num'] == 5]['Column2'], 
            s = 50, c = 'darkblue', label = 'Customer Group 6')
plt.scatter(dataset[dataset['cluster_num'] == 6]['Column1'], 
            dataset[dataset['cluster_num'] == 6]['Column2'], 
            s = 50, c = 'purple', label = 'Customer Group 7')
plt.scatter(dataset[dataset['cluster_num'] == 7]['Column1'], 
            dataset[dataset['cluster_num'] == 7]['Column2'], 
            s = 50, c = 'gray', label = 'Customer Group 8')
plt.scatter(dataset[dataset['cluster_num'] == 8]['Column1'], 
            dataset[dataset['cluster_num'] == 8]['Column2'], 
            s = 50, c = 'black', label = 'Customer Group 9')
plt.scatter(dataset[dataset['cluster_num'] == 9]['Column1'], 
            dataset[dataset['cluster_num'] == 9]['Column2'], 
            s = 50, c = 'magenta', label = 'Customer Group 10')
plt.title('Type Of Keyword')
plt.show()

# %%
viz_img(y_pred)

# %% [markdown]
# -----

# %% [markdown]
# # 5. Autoencoder + Spherical Clustering

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras import backend as K

# configure
encoding_dim = 200
input_img = Input(shape=(784,))


# layers
encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)


# Models
autoencoder = Model(input_img, decoded) # autoencoder

encoder = Model(input_img, encoded) # encoder

encoded_input = Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer(encoded_input)) # decoder

# %%
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))

def recall(y_true, y_pred):
    y_true_yn = K.round(K.clip(y_true, 0, 1))
    y_pred_yn = K.round(K.clip(y_pred, 0, 1))

    count_true_positive = K.sum(y_true_yn * y_pred_yn)
    count_true_positive_false_negative = K.sum(y_true_yn)
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())
    return recall


# train autoencoder
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=[rmse, recall])
autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=512,
                shuffle=True,
                validation_data=(x_test, x_test))


# encoding result
encoded_imgs = encoder.predict(x_train)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.3887 - rmse: 0.3167 - recall: 0.2615 - val_loss: 0.2735 - val_rmse: 0.2589 - val_recall: 0.2201
# Epoch 2/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.2655 - rmse: 0.2539 - recall: 0.2573 - val_loss: 0.2557 - val_rmse: 0.2481 - val_recall: 0.3156
# Epoch 3/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.2484 - rmse: 0.2418 - recall: 0.3497 - val_loss: 0.2384 - val_rmse: 0.2346 - val_recall: 0.3921
# Epoch 4/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.2318 - rmse: 0.2287 - recall: 0.4520 - val_loss: 0.2225 - val_rmse: 0.2218 - val_recall: 0.4950
# Epoch 5/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.2174 - rmse: 0.2172 - recall: 0.5315 - val_loss: 0.2094 - val_rmse: 0.2113 - val_recall: 0.5634
# Epoch 6/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.2057 - rmse: 0.2076 - recall: 0.5869 - val_loss: 0.1988 - val_rmse: 0.2025 - val_recall: 0.6109
# Epoch 7/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1960 - rmse: 0.1997 - recall: 0.6261 - val_loss: 0.1904 - val_rmse: 0.1955 - val_recall: 0.6302
# Epoch 8/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1881 - rmse: 0.1931 - recall: 0.6546 - val_loss: 0.1831 - val_rmse: 0.1892 - val_recall: 0.6623
# Epoch 9/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1814 - rmse: 0.1873 - recall: 0.6783 - val_loss: 0.1770 - val_rmse: 0.1839 - val_recall: 0.6821
# Epoch 10/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1757 - rmse: 0.1823 - recall: 0.6966 - val_loss: 0.1715 - val_rmse: 0.1790 - val_recall: 0.7078
# Epoch 11/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1706 - rmse: 0.1778 - recall: 0.7128 - val_loss: 0.1669 - val_rmse: 0.1748 - val_recall: 0.7170
# Epoch 12/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1661 - rmse: 0.1737 - recall: 0.7261 - val_loss: 0.1627 - val_rmse: 0.1710 - val_recall: 0.7235
# Epoch 13/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1620 - rmse: 0.1699 - recall: 0.7373 - val_loss: 0.1588 - val_rmse: 0.1673 - val_recall: 0.7353
# Epoch 14/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1583 - rmse: 0.1664 - recall: 0.7478 - val_loss: 0.1551 - val_rmse: 0.1638 - val_recall: 0.7498
# Epoch 15/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1548 - rmse: 0.1631 - recall: 0.7574 - val_loss: 0.1519 - val_rmse: 0.1606 - val_recall: 0.7573
# Epoch 16/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.1516 - rmse: 0.1600 - recall: 0.7655 - val_loss: 0.1487 - val_rmse: 0.1575 - val_recall: 0.7742
# Epoch 17/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1487 - rmse: 0.1571 - recall: 0.7737 - val_loss: 0.1458 - val_rmse: 0.1546 - val_recall: 0.7804
# Epoch 18/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1459 - rmse: 0.1543 - recall: 0.7811 - val_loss: 0.1433 - val_rmse: 0.1521 - val_recall: 0.7773
# Epoch 19/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1433 - rmse: 0.1517 - recall: 0.7870 - val_loss: 0.1407 - val_rmse: 0.1494 - val_recall: 0.7885
# Epoch 20/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1408 - rmse: 0.1492 - recall: 0.7932 - val_loss: 0.1383 - val_rmse: 0.1469 - val_recall: 0.7956
# Epoch 21/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.1385 - rmse: 0.1468 - recall: 0.7987 - val_loss: 0.1360 - val_rmse: 0.1446 - val_recall: 0.8054
# Epoch 22/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1364 - rmse: 0.1446 - recall: 0.8041 - val_loss: 0.1340 - val_rmse: 0.1425 - val_recall: 0.8004
# Epoch 23/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1343 - rmse: 0.1424 - recall: 0.8084 - val_loss: 0.1319 - val_rmse: 0.1402 - val_recall: 0.8092
# Epoch 24/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1324 - rmse: 0.1404 - recall: 0.8129 - val_loss: 0.1300 - val_rmse: 0.1382 - val_recall: 0.8185
# Epoch 25/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1305 - rmse: 0.1384 - recall: 0.8174 - val_loss: 0.1283 - val_rmse: 0.1363 - val_recall: 0.8152
# Epoch 26/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.1288 - rmse: 0.1365 - recall: 0.8208 - val_loss: 0.1265 - val_rmse: 0.1343 - val_recall: 0.8238
# Epoch 27/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1271 - rmse: 0.1346 - recall: 0.8248 - val_loss: 0.1249 - val_rmse: 0.1326 - val_recall: 0.8229
# Epoch 28/100
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1255 - rmse: 0.1328 - recall: 0.8282 - val_loss: 0.1232 - val_rmse: 0.1307 - val_recall: 0.8311
# Epoch 29/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1239 - rmse: 0.1311 - recall: 0.8317 - val_loss: 0.1218 - val_rmse: 0.1291 - val_recall: 0.8307
# Epoch 30/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1224 - rmse: 0.1294 - recall: 0.8347 - val_loss: 0.1202 - val_rmse: 0.1273 - val_recall: 0.8381
# Epoch 31/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1210 - rmse: 0.1278 - recall: 0.8377 - val_loss: 0.1188 - val_rmse: 0.1257 - val_recall: 0.8414
# Epoch 32/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.1196 - rmse: 0.1262 - recall: 0.8407 - val_loss: 0.1175 - val_rmse: 0.1241 - val_recall: 0.8439
# Epoch 33/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1182 - rmse: 0.1246 - recall: 0.8434 - val_loss: 0.1161 - val_rmse: 0.1225 - val_recall: 0.8471
# Epoch 34/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1169 - rmse: 0.1231 - recall: 0.8460 - val_loss: 0.1149 - val_rmse: 0.1211 - val_recall: 0.8469
# Epoch 35/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1157 - rmse: 0.1216 - recall: 0.8485 - val_loss: 0.1138 - val_rmse: 0.1198 - val_recall: 0.8424
# Epoch 36/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1145 - rmse: 0.1201 - recall: 0.8506 - val_loss: 0.1124 - val_rmse: 0.1181 - val_recall: 0.8517
# Epoch 37/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1133 - rmse: 0.1187 - recall: 0.8532 - val_loss: 0.1113 - val_rmse: 0.1168 - val_recall: 0.8521
# Epoch 38/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1121 - rmse: 0.1173 - recall: 0.8551 - val_loss: 0.1101 - val_rmse: 0.1153 - val_recall: 0.8575
# Epoch 39/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1110 - rmse: 0.1160 - recall: 0.8574 - val_loss: 0.1091 - val_rmse: 0.1139 - val_recall: 0.8595
# Epoch 40/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.1100 - rmse: 0.1146 - recall: 0.8595 - val_loss: 0.1081 - val_rmse: 0.1129 - val_recall: 0.8547
# Epoch 41/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.1089 - rmse: 0.1134 - recall: 0.8611 - val_loss: 0.1070 - val_rmse: 0.1114 - val_recall: 0.8630
# Epoch 42/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.1080 - rmse: 0.1121 - recall: 0.8632 - val_loss: 0.1061 - val_rmse: 0.1103 - val_recall: 0.8609
# Epoch 43/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1070 - rmse: 0.1109 - recall: 0.8647 - val_loss: 0.1051 - val_rmse: 0.1090 - val_recall: 0.8651
# Epoch 44/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.1061 - rmse: 0.1097 - recall: 0.8664 - val_loss: 0.1042 - val_rmse: 0.1077 - val_recall: 0.8686
# Epoch 45/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1052 - rmse: 0.1086 - recall: 0.8682 - val_loss: 0.1033 - val_rmse: 0.1066 - val_recall: 0.8696
# Epoch 46/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1043 - rmse: 0.1074 - recall: 0.8697 - val_loss: 0.1026 - val_rmse: 0.1057 - val_recall: 0.8669
# Epoch 47/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1035 - rmse: 0.1064 - recall: 0.8710 - val_loss: 0.1017 - val_rmse: 0.1045 - val_recall: 0.8701
# Epoch 48/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1027 - rmse: 0.1053 - recall: 0.8724 - val_loss: 0.1009 - val_rmse: 0.1034 - val_recall: 0.8725
# Epoch 49/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1019 - rmse: 0.1043 - recall: 0.8738 - val_loss: 0.1002 - val_rmse: 0.1024 - val_recall: 0.8759
# Epoch 50/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1012 - rmse: 0.1033 - recall: 0.8751 - val_loss: 0.0994 - val_rmse: 0.1014 - val_recall: 0.8772
# Epoch 51/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1005 - rmse: 0.1024 - recall: 0.8764 - val_loss: 0.0988 - val_rmse: 0.1005 - val_recall: 0.8794
# Epoch 52/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0998 - rmse: 0.1014 - recall: 0.8776 - val_loss: 0.0981 - val_rmse: 0.0995 - val_recall: 0.8803
# Epoch 53/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0991 - rmse: 0.1005 - recall: 0.8788 - val_loss: 0.0975 - val_rmse: 0.0988 - val_recall: 0.8784
# Epoch 54/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0985 - rmse: 0.0997 - recall: 0.8797 - val_loss: 0.0968 - val_rmse: 0.0979 - val_recall: 0.8802
# Epoch 55/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0979 - rmse: 0.0988 - recall: 0.8808 - val_loss: 0.0962 - val_rmse: 0.0970 - val_recall: 0.8829
# Epoch 56/100
# 60000/60000 [==============================] - 2s 39us/step - loss: 0.0973 - rmse: 0.0980 - recall: 0.8819 - val_loss: 0.0957 - val_rmse: 0.0961 - val_recall: 0.8875
# Epoch 57/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0967 - rmse: 0.0972 - recall: 0.8829 - val_loss: 0.0951 - val_rmse: 0.0954 - val_recall: 0.8853
# Epoch 58/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0962 - rmse: 0.0965 - recall: 0.8837 - val_loss: 0.0946 - val_rmse: 0.0947 - val_recall: 0.8852
# Epoch 59/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0957 - rmse: 0.0957 - recall: 0.8847 - val_loss: 0.0941 - val_rmse: 0.0940 - val_recall: 0.8865
# Epoch 60/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0951 - rmse: 0.0950 - recall: 0.8855 - val_loss: 0.0936 - val_rmse: 0.0933 - val_recall: 0.8877
# Epoch 61/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0947 - rmse: 0.0943 - recall: 0.8864 - val_loss: 0.0931 - val_rmse: 0.0925 - val_recall: 0.8900
# Epoch 62/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0942 - rmse: 0.0937 - recall: 0.8873 - val_loss: 0.0926 - val_rmse: 0.0919 - val_recall: 0.8888
# Epoch 63/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0937 - rmse: 0.0930 - recall: 0.8880 - val_loss: 0.0922 - val_rmse: 0.0912 - val_recall: 0.8918
# Epoch 64/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0933 - rmse: 0.0924 - recall: 0.8889 - val_loss: 0.0918 - val_rmse: 0.0907 - val_recall: 0.8892
# Epoch 65/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0929 - rmse: 0.0918 - recall: 0.8895 - val_loss: 0.0914 - val_rmse: 0.0902 - val_recall: 0.8880
# Epoch 66/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0924 - rmse: 0.0912 - recall: 0.8902 - val_loss: 0.0910 - val_rmse: 0.0895 - val_recall: 0.8912
# Epoch 67/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0920 - rmse: 0.0906 - recall: 0.8910 - val_loss: 0.0906 - val_rmse: 0.0889 - val_recall: 0.8919
# Epoch 68/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0917 - rmse: 0.0900 - recall: 0.8917 - val_loss: 0.0902 - val_rmse: 0.0883 - val_recall: 0.8941
# Epoch 69/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0913 - rmse: 0.0895 - recall: 0.8924 - val_loss: 0.0898 - val_rmse: 0.0878 - val_recall: 0.8926
# Epoch 70/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0909 - rmse: 0.0889 - recall: 0.8930 - val_loss: 0.0895 - val_rmse: 0.0872 - val_recall: 0.8961
# Epoch 71/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0906 - rmse: 0.0884 - recall: 0.8937 - val_loss: 0.0891 - val_rmse: 0.0867 - val_recall: 0.8962
# Epoch 72/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0902 - rmse: 0.0879 - recall: 0.8944 - val_loss: 0.0888 - val_rmse: 0.0862 - val_recall: 0.8970
# Epoch 73/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0899 - rmse: 0.0874 - recall: 0.8949 - val_loss: 0.0885 - val_rmse: 0.0857 - val_recall: 0.8980
# Epoch 74/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0896 - rmse: 0.0869 - recall: 0.8956 - val_loss: 0.0882 - val_rmse: 0.0853 - val_recall: 0.8969
# Epoch 75/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0893 - rmse: 0.0865 - recall: 0.8962 - val_loss: 0.0879 - val_rmse: 0.0848 - val_recall: 0.8985
# Epoch 76/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0890 - rmse: 0.0860 - recall: 0.8968 - val_loss: 0.0876 - val_rmse: 0.0844 - val_recall: 0.8973
# Epoch 77/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0887 - rmse: 0.0856 - recall: 0.8973 - val_loss: 0.0873 - val_rmse: 0.0839 - val_recall: 0.8991
# Epoch 78/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0884 - rmse: 0.0852 - recall: 0.8979 - val_loss: 0.0870 - val_rmse: 0.0836 - val_recall: 0.8984
# Epoch 79/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0881 - rmse: 0.0847 - recall: 0.8984 - val_loss: 0.0868 - val_rmse: 0.0831 - val_recall: 0.9008
# Epoch 80/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0878 - rmse: 0.0843 - recall: 0.8990 - val_loss: 0.0865 - val_rmse: 0.0827 - val_recall: 0.9004
# Epoch 81/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0876 - rmse: 0.0839 - recall: 0.8995 - val_loss: 0.0862 - val_rmse: 0.0823 - val_recall: 0.9015
# Epoch 82/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0873 - rmse: 0.0835 - recall: 0.9001 - val_loss: 0.0860 - val_rmse: 0.0819 - val_recall: 0.9017
# Epoch 83/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0871 - rmse: 0.0831 - recall: 0.9006 - val_loss: 0.0858 - val_rmse: 0.0816 - val_recall: 0.9011
# Epoch 84/100
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.0868 - rmse: 0.0827 - recall: 0.9011 - val_loss: 0.0855 - val_rmse: 0.0811 - val_recall: 0.9055
# Epoch 85/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0866 - rmse: 0.0824 - recall: 0.9017 - val_loss: 0.0853 - val_rmse: 0.0808 - val_recall: 0.9040
# Epoch 86/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0863 - rmse: 0.0820 - recall: 0.9021 - val_loss: 0.0851 - val_rmse: 0.0804 - val_recall: 0.9036
# Epoch 87/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0861 - rmse: 0.0816 - recall: 0.9026 - val_loss: 0.0849 - val_rmse: 0.0801 - val_recall: 0.9047
# Epoch 88/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0859 - rmse: 0.0813 - recall: 0.9030 - val_loss: 0.0846 - val_rmse: 0.0797 - val_recall: 0.9069
# Epoch 89/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0857 - rmse: 0.0810 - recall: 0.9035 - val_loss: 0.0844 - val_rmse: 0.0795 - val_recall: 0.9036
# Epoch 90/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0855 - rmse: 0.0806 - recall: 0.9039 - val_loss: 0.0842 - val_rmse: 0.0791 - val_recall: 0.9063
# Epoch 91/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0853 - rmse: 0.0803 - recall: 0.9044 - val_loss: 0.0840 - val_rmse: 0.0787 - val_recall: 0.9069
# Epoch 92/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0851 - rmse: 0.0800 - recall: 0.9048 - val_loss: 0.0838 - val_rmse: 0.0785 - val_recall: 0.9056
# Epoch 93/100
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0849 - rmse: 0.0796 - recall: 0.9052 - val_loss: 0.0837 - val_rmse: 0.0781 - val_recall: 0.9086
# Epoch 94/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0847 - rmse: 0.0793 - recall: 0.9057 - val_loss: 0.0835 - val_rmse: 0.0778 - val_recall: 0.9078
# Epoch 95/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0845 - rmse: 0.0790 - recall: 0.9061 - val_loss: 0.0833 - val_rmse: 0.0774 - val_recall: 0.9100
# Epoch 96/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0843 - rmse: 0.0787 - recall: 0.9065 - val_loss: 0.0831 - val_rmse: 0.0772 - val_recall: 0.9102
# Epoch 97/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0841 - rmse: 0.0784 - recall: 0.9070 - val_loss: 0.0829 - val_rmse: 0.0769 - val_recall: 0.9093
# Epoch 98/100
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0839 - rmse: 0.0781 - recall: 0.9073 - val_loss: 0.0828 - val_rmse: 0.0767 - val_recall: 0.9085
# Epoch 99/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0838 - rmse: 0.0779 - recall: 0.9077 - val_loss: 0.0826 - val_rmse: 0.0764 - val_recall: 0.9084
# Epoch 100/100
# 60000/60000 [==============================] - 2s 35us/step - loss: 0.0836 - rmse: 0.0776 - recall: 0.9080 - val_loss: 0.0824 - val_rmse: 0.0761 - val_recall: 0.9098

# %%
encoded_imgs.shape
# Out:
# (60000, 200)

# %%
from spherecluster import SphericalKMeans

skm = SphericalKMeans(n_clusters=10)
skm.fit(x_train)
# Out:
# SphericalKMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=10,
#         n_init=10, n_jobs=1, normalize=True, random_state=None, tol=0.0001,
#         verbose=0)

# %%
viz_img(skm.labels_)
